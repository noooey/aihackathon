# %%
# !pip install autogluon
# !pip install numpy pandas
# !pip install scikit-learn
# Out:
# Requirement already satisfied: autogluon in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (0.8.2)
# Requirement already satisfied: autogluon.core[all]==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon) (0.8.2)
# Requirement already satisfied: autogluon.features==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon) (0.8.2)
# Requirement already satisfied: autogluon.tabular[all]==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon) (0.8.2)
# Requirement already satisfied: autogluon.multimodal==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon) (0.8.2)
# Requirement already satisfied: autogluon.timeseries[all]==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon) (0.8.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.24.4)
# Requirement already satisfied: scipy<1.12,>=1.5.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.11.2)
# Requirement already satisfied: scikit-learn<1.3,>=1.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.2.2)
# Requirement already satisfied: networkx<4,>=3.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (3.1)
# Requirement already satisfied: pandas<1.6,>=1.4.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.5.3)
# Requirement already satisfied: tqdm<5,>=4.38 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (4.65.2)
# Requirement already satisfied: requests in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (2.28.2)
# Requirement already satisfied: matplotlib in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (3.7.3)
# Requirement already satisfied: boto3<2,>=1.10 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.28.47)
# Requirement already satisfied: autogluon.common==0.8.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (0.8.2)
# Requirement already satisfied: hyperopt<0.2.8,>=0.2.7 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (0.2.7)
# Requirement already satisfied: ray[default]<2.4,>=2.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (2.3.1)
# Requirement already satisfied: pydantic<2.0,>=1.10.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.10.12)
# Requirement already satisfied: grpcio<=1.50.0,>=1.42.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.core[all]==0.8.2->autogluon) (1.48.2)
# Requirement already satisfied: Pillow<9.6,>=9.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (9.5.0)
# Requirement already satisfied: jsonschema<4.18,>=4.14 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (4.17.3)
# Requirement already satisfied: seqeval<1.3.0,>=1.2.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.2.2)
# Requirement already satisfied: evaluate<0.4.0,>=0.2.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.3.0)
# Requirement already satisfied: accelerate<0.17,>=0.9 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.16.0)
# Requirement already satisfied: timm<0.10.0,>=0.9.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.9.7)
# Requirement already satisfied: torch<1.14,>=1.9 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.13.1)
# Requirement already satisfied: torchvision<0.15.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.14.1)
# Requirement already satisfied: scikit-image<0.20.0,>=0.19.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.19.3)
# Requirement already satisfied: pytorch-lightning<1.10.0,>=1.9.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.9.5)
# Requirement already satisfied: text-unidecode<1.4,>=1.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.3)
# Requirement already satisfied: torchmetrics<0.12.0,>=0.11.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.11.4)
# Requirement already satisfied: transformers[sentencepiece]<4.27.0,>=4.23.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (4.26.1)
# Requirement already satisfied: nptyping<2.5.0,>=1.4.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (2.4.1)
# Requirement already satisfied: omegaconf<2.3.0,>=2.1.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (2.2.3)
# Requirement already satisfied: pytorch-metric-learning<2.0,>=1.3.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.7.3)
# Requirement already satisfied: nlpaug<1.2.0,>=1.1.10 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (1.1.11)
# Requirement already satisfied: nltk<4.0.0,>=3.4.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (3.8.1)
# Requirement already satisfied: openmim<0.4.0,>=0.3.7 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.3.9)
# Requirement already satisfied: defusedxml<0.7.2,>=0.7.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.7.1)
# Requirement already satisfied: jinja2<3.2,>=3.0.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (3.1.2)
# Requirement already satisfied: tensorboard<3,>=2.9 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (2.14.0)
# Requirement already satisfied: pytesseract<0.3.11,>=0.3.9 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.multimodal==0.8.2->autogluon) (0.3.10)
# Requirement already satisfied: lightgbm<3.4,>=3.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.tabular[all]==0.8.2->autogluon) (3.3.5)
# Requirement already satisfied: xgboost<1.8,>=1.6 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.tabular[all]==0.8.2->autogluon) (1.7.6)
# Requirement already satisfied: fastai<2.8,>=2.3.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.tabular[all]==0.8.2->autogluon) (2.7.12)
# Requirement already satisfied: catboost<1.3,>=1.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.tabular[all]==0.8.2->autogluon) (1.1.1)
# Requirement already satisfied: joblib<2,>=1.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (1.3.2)
# Requirement already satisfied: statsmodels<0.15,>=0.13.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (0.14.0)
# Requirement already satisfied: gluonts<0.14,>=0.13.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (0.13.4)
# Requirement already satisfied: statsforecast<1.5,>=1.4.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (1.4.0)
# Requirement already satisfied: mlforecast<0.7.4,>=0.7.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (0.7.3)
# Requirement already satisfied: ujson<6,>=5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.timeseries[all]==0.8.2->autogluon) (5.8.0)
# Requirement already satisfied: psutil<6,>=5.7.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.common==0.8.2->autogluon.core[all]==0.8.2->autogluon) (5.9.0)
# Requirement already satisfied: setuptools in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from autogluon.common==0.8.2->autogluon.core[all]==0.8.2->autogluon) (60.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from accelerate<0.17,>=0.9->autogluon.multimodal==0.8.2->autogluon) (23.1)
# Requirement already satisfied: pyyaml in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from accelerate<0.17,>=0.9->autogluon.multimodal==0.8.2->autogluon) (6.0.1)
# Requirement already satisfied: botocore<1.32.0,>=1.31.47 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core[all]==0.8.2->autogluon) (1.31.47)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core[all]==0.8.2->autogluon) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from boto3<2,>=1.10->autogluon.core[all]==0.8.2->autogluon) (0.6.2)
# Requirement already satisfied: graphviz in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==0.8.2->autogluon) (0.20.1)
# Requirement already satisfied: plotly in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==0.8.2->autogluon) (5.16.1)
# Requirement already satisfied: six in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from catboost<1.3,>=1.1->autogluon.tabular[all]==0.8.2->autogluon) (1.16.0)
# Requirement already satisfied: datasets>=2.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (2.14.5)
# Requirement already satisfied: dill in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (0.3.7)
# Requirement already satisfied: xxhash in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (3.3.0)
# Requirement already satisfied: multiprocess in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (0.70.15)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (2023.6.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (0.17.1)
# Requirement already satisfied: responses<0.19 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (0.18.0)
# Requirement already satisfied: pip in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (23.2.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (0.0.7)
# Requirement already satisfied: fastcore<1.6,>=1.5.29 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (1.5.29)
# Requirement already satisfied: fastprogress>=0.2.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (1.0.3)
# Requirement already satisfied: spacy<4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (3.6.1)
# Requirement already satisfied: toolz~=0.10 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from gluonts<0.14,>=0.13.1->autogluon.timeseries[all]==0.8.2->autogluon) (0.12.0)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from gluonts<0.14,>=0.13.1->autogluon.timeseries[all]==0.8.2->autogluon) (4.7.1)
# Requirement already satisfied: future in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.8.2->autogluon) (0.18.3)
# Requirement already satisfied: cloudpickle in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.8.2->autogluon) (2.2.1)
# Requirement already satisfied: py4j in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from hyperopt<0.2.8,>=0.2.7->autogluon.core[all]==0.8.2->autogluon) (0.10.9.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from jinja2<3.2,>=3.0.3->autogluon.multimodal==0.8.2->autogluon) (2.1.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal==0.8.2->autogluon) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from jsonschema<4.18,>=4.14->autogluon.multimodal==0.8.2->autogluon) (0.19.3)
# Requirement already satisfied: wheel in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from lightgbm<3.4,>=3.3->autogluon.tabular[all]==0.8.2->autogluon) (0.41.2)
# Requirement already satisfied: numba in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from mlforecast<0.7.4,>=0.7.0->autogluon.timeseries[all]==0.8.2->autogluon) (0.57.1)
# Requirement already satisfied: window-ops in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from mlforecast<0.7.4,>=0.7.0->autogluon.timeseries[all]==0.8.2->autogluon) (0.0.14)
# Requirement already satisfied: gdown>=4.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.8.2->autogluon) (4.7.1)
# Requirement already satisfied: click in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.8.2->autogluon) (8.1.7)
# Requirement already satisfied: regex>=2021.8.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from nltk<4.0.0,>=3.4.5->autogluon.multimodal==0.8.2->autogluon) (2023.8.8)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from omegaconf<2.3.0,>=2.1.1->autogluon.multimodal==0.8.2->autogluon) (4.9.3)
# Requirement already satisfied: colorama in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.4.6)
# Requirement already satisfied: model-index in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.1.11)
# Requirement already satisfied: opendatalab in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.0.10)
# Requirement already satisfied: rich in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (13.4.2)
# Requirement already satisfied: tabulate in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pandas<1.6,>=1.4.1->autogluon.core[all]==0.8.2->autogluon) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pandas<1.6,>=1.4.1->autogluon.core[all]==0.8.2->autogluon) (2023.3.post1)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pytorch-lightning<1.10.0,>=1.9.0->autogluon.multimodal==0.8.2->autogluon) (0.9.0)
# Requirement already satisfied: filelock in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (3.12.4)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.0.5)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (3.20.2)
# Requirement already satisfied: aiosignal in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.3.1)
# Requirement already satisfied: frozenlist in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.4.0)
# Requirement already satisfied: virtualenv>=20.0.24 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (20.24.5)
# Requirement already satisfied: aiohttp>=3.7 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (3.8.5)
# Requirement already satisfied: aiohttp-cors in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.7.0)
# Requirement already satisfied: colorful in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.5.5)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.3.14)
# Requirement already satisfied: gpustat>=1.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.1.1)
# Requirement already satisfied: opencensus in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.11.2)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.17.1)
# Requirement already satisfied: smart-open in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (6.4.0)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (2.6.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.8.2->autogluon) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.8.2->autogluon) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.8.2->autogluon) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.8.2->autogluon) (2023.7.22)
# Requirement already satisfied: imageio>=2.4.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.8.2->autogluon) (2.31.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.8.2->autogluon) (2023.8.30)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-image<0.20.0,>=0.19.1->autogluon.multimodal==0.8.2->autogluon) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->autogluon.core[all]==0.8.2->autogluon) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from statsmodels<0.15,>=0.13.0->autogluon.timeseries[all]==0.8.2->autogluon) (0.5.3)
# Requirement already satisfied: absl-py>=0.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (2.3.7)
# Requirement already satisfied: safetensors in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from timm<0.10.0,>=0.9.2->autogluon.multimodal==0.8.2->autogluon) (0.3.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from transformers[sentencepiece]<4.27.0,>=4.23.0->autogluon.multimodal==0.8.2->autogluon) (0.13.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from transformers[sentencepiece]<4.27.0,>=4.23.0->autogluon.multimodal==0.8.2->autogluon) (0.1.99)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from matplotlib->autogluon.core[all]==0.8.2->autogluon) (6.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from aiohttp>=3.7->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.9.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate<0.4.0,>=0.2.2->autogluon.multimodal==0.8.2->autogluon) (13.0.0)
# Requirement already satisfied: beautifulsoup4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.8.2->autogluon) (4.12.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (1.3.1)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (12.535.108)
# Requirement already satisfied: blessed>=1.17.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from gpustat>=1.0.0->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.20.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->autogluon.core[all]==0.8.2->autogluon) (3.16.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (6.8.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from numba->mlforecast<0.7.4,>=0.7.0->autogluon.timeseries[all]==0.8.2->autogluon) (0.40.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (2.4.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (2.0.9)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (0.10.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (3.3.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.3.7)
# Requirement already satisfied: platformdirs<4,>=3.9.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from virtualenv>=20.0.24->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (3.10.0)
# Requirement already satisfied: ordered-set in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from model-index->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (4.1.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from opencensus->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from opencensus->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (2.11.1)
# Requirement already satisfied: pycryptodome in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (3.18.0)
# Requirement already satisfied: openxlab in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.0.25)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from plotly->catboost<1.3,>=1.1->autogluon.tabular[all]==0.8.2->autogluon) (8.2.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (2.16.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (0.2.6)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]<2.4,>=2.3->autogluon.core[all]==0.8.2->autogluon) (1.60.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<3,>=2.9->autogluon.multimodal==0.8.2->autogluon) (3.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.8->spacy<4->fastai<2.8,>=2.3.1->autogluon.tabular[all]==0.8.2->autogluon) (0.1.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from beautifulsoup4->gdown>=4.0.0->nlpaug<1.2.0,>=1.1.10->autogluon.multimodal==0.8.2->autogluon) (2.5)
# Requirement already satisfied: oss2~=2.17.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (2.17.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from requests->autogluon.core[all]==0.8.2->autogluon) (1.7.1)
# Requirement already satisfied: crcmod>=1.7 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (1.7)
# Requirement already satisfied: aliyun-python-sdk-kms>=2.4.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (2.16.2)
# Requirement already satisfied: aliyun-python-sdk-core>=2.13.12 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (2.13.36)
# Requirement already satisfied: cryptography>=2.6.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (41.0.3)
# Requirement already satisfied: cffi>=1.12 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (1.15.1)
# Requirement already satisfied: pycparser in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.6.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim<0.4.0,>=0.3.7->autogluon.multimodal==0.8.2->autogluon) (2.21)
# Requirement already satisfied: numpy in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (1.24.4)
# Requirement already satisfied: pandas in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: scikit-learn in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-learn) (1.24.4)
# Requirement already satisfied: scipy>=1.3.2 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-learn) (1.11.2)
# Requirement already satisfied: joblib>=1.1.1 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bello/anaconda3/envs/tomato/lib/python3.9/site-packages (from scikit-learn) (3.2.0)

# %%
from autogluon.tabular import TabularPredictor, TabularDataset
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
train_df = pd.read_csv('2023_smartFarm_AI_hackathon_dataset.csv') # input for train dataset
# test_data = pd.read_csv('./test data location.csv')
train_data = TabularDataset(train_df)
time_limit = 3600 * 1 # hrs
label = 'HeatingEnergyUsage_cumsum'

# 'r2' for r2 score & 'root_mean_squared_error' for RMSE
eval_metric = 'accuracy' 
r2_metric = 'r2'
rmse_metric = 'root_mean_squared_error'

output_directory = './autogluon_model_log' # output directory
predictor_directory = './autogluon_model_predict' # predictore directory

# autogluon train
predictor = TabularPredictor(
    label=label, 
    eval_metric=rmse_metric, 
    path=output_directory
).fit(
    train_data,
    presets='best_quality', 
    time_limit=time_limit, 
    ag_args_fit={'num_gpus': 0, 'num_cpus': 8}
    # training for a specific model ref: 'https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html'
    #hyperparameters={'GBM': {}},
    #num_bag_folds=2,      
    #num_stack_levels=2,
    )

# extra train
# additional_hyperparmeter = 'GBM'
# predictor.fit_extra(hyperparameters=additional_hyperparmeter)

### result (leaderboard)
leaderboard = predictor.leaderboard(silent=False)
print(leaderboard)

log_path = os.path.join(output_directory, 'train.log')
with open(log_path, 'w') as f:
    f.write(str(leaderboard))

print(f"Logs saved to {log_path}")

predictor.save(predictor_directory)
# Out:
# Presets specified: ['best_quality']
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=20
# Beginning AutoGluon training ... Time limit = 300s
# AutoGluon will save models to "./autogluon_model_log/"
# AutoGluon Version:  0.8.2
# Python Version:     3.9.18
# Operating System:   Darwin
# Platform Machine:   arm64
# Platform Version:   Darwin Kernel Version 22.6.0: Wed Jul  5 22:22:52 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T8103
# Disk Space Avail:   76.80 GB / 245.11 GB (31.3%)
# Train Data Rows:    84840
# Train Data Columns: 49
# Label Column: HeatingEnergyUsage_cumsum
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (4171031.468732149, 0.0, 144977.03704, 572925.17288)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    3292.82 MB
# 	Train Data (Original)  Memory Usage: 38.09 MB (1.2% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 8): ['daysuplyqy', 'lefstalklt', 'frtstSetCo', 'pllnLt', 'flanJnt', 'hvstJnt', 'flwrCo', 'frtstJnt']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])  : 36 | ['inTp', 'inHd', 'otmsuplyqy', 'acSlrdQy', 'cunt', ...]
# 		('int', [])    :  4 | ['date', 'frmYear', 'frmWeek', 'frmAr']
# 		('object', []) :  1 | ['frmDist']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) :  1 | ['frmDist']
# 		('float', [])    : 36 | ['inTp', 'inHd', 'otmsuplyqy', 'acSlrdQy', 'cunt', ...]
# 		('int', [])      :  4 | ['date', 'frmYear', 'frmWeek', 'frmAr']
# 	0.3s = Fit runtime
# 	41 features in original data used to generate 41 features in processed data.
# 	Train Data (Processed) Memory Usage: 27.32 MB (0.8% of available memory)
# Data preprocessing and feature engineering runtime = 0.37s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 199.71s of the 299.63s of remaining time.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[35], line 16
#      13 predictor_directory = './autogluon_model_predict' # predictore directory
#      15 # autogluon train
# ---> 16 predictor = TabularPredictor(
#      17     label=label,
#      18     eval_metric=rmse_metric,
#      19     path=output_directory
#      20 ).fit(
#      21     train_data,
#      22     presets='best_quality',
#      23     time_limit=time_limit,
#      24     ag_args_fit={'num_gpus': 0, 'num_cpus': 8}
#      25     # training for a specific model ref: 'https://auto.gluon.ai/stable/api/autogluon.tabular.TabularPredictor.fit.html'
#      26     #hyperparameters={'GBM': {}},
#      27     #num_bag_folds=2,
#      28     #num_stack_levels=2,
#      29     )
#      31 # extra train
#      32 # additional_hyperparmeter = 'GBM'
#      33 # predictor.fit_extra(hyperparameters=additional_hyperparmeter)
#      34
#      35 ### result (leaderboard)
#      36 leaderboard = predictor.leaderboard(silent=False)
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/utils/decorators.py:31, in unpack.<locals>._unpack_inner.<locals>._call(*args, **kwargs)
#      28 @functools.wraps(f)
#      29 def _call(*args, **kwargs):
#      30     gargs, gkwargs = g(*other_args, *args, **kwargs)
# ---> 31     return f(*gargs, **gkwargs)
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/predictor/predictor.py:986, in TabularPredictor.fit(self, train_data, tuning_data, time_limit, presets, hyperparameters, feature_metadata, infer_limit, infer_limit_batch_size, fit_weighted_ensemble, calibrate_decision_threshold, num_cpus, num_gpus, **kwargs)
#     984     aux_kwargs["fit_weighted_ensemble"] = False
#     985 self.save(silent=True)  # Save predictor to disk to enable prediction and training after interrupt
# --> 986 self._learner.fit(
#     987     X=train_data,
#     988     X_val=tuning_data,
#     989     X_unlabeled=unlabeled_data,
#     990     holdout_frac=holdout_frac,
#     991     num_bag_folds=num_bag_folds,
#     992     num_bag_sets=num_bag_sets,
#     993     num_stack_levels=num_stack_levels,
#     994     hyperparameters=hyperparameters,
#     995     core_kwargs=core_kwargs,
#     996     aux_kwargs=aux_kwargs,
#     997     time_limit=time_limit,
#     998     infer_limit=infer_limit,
#     999     infer_limit_batch_size=infer_limit_batch_size,
#    1000     verbosity=verbosity,
#    1001     use_bag_holdout=use_bag_holdout,
#    1002 )
#    1003 self._set_post_fit_vars()
#    1005 self._post_fit(
#    1006     keep_only_best=kwargs["keep_only_best"],
#    1007     refit_full=kwargs["refit_full"],
#    (...)
#    1012     infer_limit=infer_limit,
#    1013 )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/learner/abstract_learner.py:159, in AbstractTabularLearner.fit(self, X, X_val, **kwargs)
#     157     raise AssertionError("Learner is already fit.")
#     158 self._validate_fit_input(X=X, X_val=X_val, **kwargs)
# --> 159 return self._fit(X=X, X_val=X_val, **kwargs)
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/learner/default_learner.py:157, in DefaultLearner._fit(self, X, X_val, X_unlabeled, holdout_frac, num_bag_folds, num_bag_sets, time_limit, infer_limit, infer_limit_batch_size, verbosity, **trainer_fit_kwargs)
#     154     self.eval_metric = trainer.eval_metric
#     156 self.save()
# --> 157 trainer.fit(
#     158     X=X,
#     159     y=y,
#     160     X_val=X_val,
#     161     y_val=y_val,
#     162     X_unlabeled=X_unlabeled,
#     163     holdout_frac=holdout_frac,
#     164     time_limit=time_limit_trainer,
#     165     infer_limit=infer_limit,
#     166     infer_limit_batch_size=infer_limit_batch_size,
#     167     groups=groups,
#     168     **trainer_fit_kwargs,
#     169 )
#     170 self.save_trainer(trainer=trainer)
#     171 time_end = time.time()
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/trainer/auto_trainer.py:114, in AutoTrainer.fit(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, holdout_frac, num_stack_levels, core_kwargs, aux_kwargs, time_limit, infer_limit, infer_limit_batch_size, use_bag_holdout, groups, **kwargs)
#     111 log_str += "}"
#     112 logger.log(20, log_str)
# --> 114 self._train_multi_and_ensemble(
#     115     X=X,
#     116     y=y,
#     117     X_val=X_val,
#     118     y_val=y_val,
#     119     X_unlabeled=X_unlabeled,
#     120     hyperparameters=hyperparameters,
#     121     num_stack_levels=num_stack_levels,
#     122     time_limit=time_limit,
#     123     core_kwargs=core_kwargs,
#     124     aux_kwargs=aux_kwargs,
#     125     infer_limit=infer_limit,
#     126     infer_limit_batch_size=infer_limit_batch_size,
#     127     groups=groups,
#     128 )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:2371, in AbstractTrainer._train_multi_and_ensemble(self, X, y, X_val, y_val, hyperparameters, X_unlabeled, num_stack_levels, time_limit, groups, **kwargs)
#    2369     self._num_rows_val = len(X_val)
#    2370 self._num_cols_train = len(list(X.columns))
# -> 2371 model_names_fit = self.train_multi_levels(
#    2372     X,
#    2373     y,
#    2374     hyperparameters=hyperparameters,
#    2375     X_val=X_val,
#    2376     y_val=y_val,
#    2377     X_unlabeled=X_unlabeled,
#    2378     level_start=1,
#    2379     level_end=num_stack_levels + 1,
#    2380     time_limit=time_limit,
#    2381     **kwargs,
#    2382 )
#    2383 if len(self.get_model_names()) == 0:
#    2384     raise ValueError("AutoGluon did not successfully train any models")
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:395, in AbstractTrainer.train_multi_levels(self, X, y, hyperparameters, X_val, y_val, X_unlabeled, base_model_names, core_kwargs, aux_kwargs, level_start, level_end, time_limit, name_suffix, relative_stack, level_time_modifier, infer_limit, infer_limit_batch_size)
#     393         core_kwargs_level["time_limit"] = core_kwargs_level.get("time_limit", time_limit_core)
#     394         aux_kwargs_level["time_limit"] = aux_kwargs_level.get("time_limit", time_limit_aux)
# --> 395     base_model_names, aux_models = self.stack_new_level(
#     396         X=X,
#     397         y=y,
#     398         X_val=X_val,
#     399         y_val=y_val,
#     400         X_unlabeled=X_unlabeled,
#     401         models=hyperparameters,
#     402         level=level,
#     403         base_model_names=base_model_names,
#     404         core_kwargs=core_kwargs_level,
#     405         aux_kwargs=aux_kwargs_level,
#     406         name_suffix=name_suffix,
#     407         infer_limit=infer_limit,
#     408         infer_limit_batch_size=infer_limit_batch_size,
#     409     )
#     410     model_names_fit += base_model_names + aux_models
#     411 if self.model_best is None and len(model_names_fit) != 0:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:539, in AbstractTrainer.stack_new_level(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, core_kwargs, aux_kwargs, name_suffix, infer_limit, infer_limit_batch_size)
#     537     core_kwargs["name_suffix"] = core_kwargs.get("name_suffix", "") + name_suffix
#     538     aux_kwargs["name_suffix"] = aux_kwargs.get("name_suffix", "") + name_suffix
# --> 539 core_models = self.stack_new_level_core(
#     540     X=X,
#     541     y=y,
#     542     X_val=X_val,
#     543     y_val=y_val,
#     544     X_unlabeled=X_unlabeled,
#     545     models=models,
#     546     level=level,
#     547     infer_limit=infer_limit,
#     548     infer_limit_batch_size=infer_limit_batch_size,
#     549     base_model_names=base_model_names,
#     550     **core_kwargs,
#     551 )
#     553 if X_val is None:
#     554     aux_models = self.stack_new_level_aux(
#     555         X=X, y=y, base_model_names=core_models, level=level + 1, infer_limit=infer_limit, infer_limit_batch_size=infer_limit_batch_size, **aux_kwargs
#     556     )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:673, in AbstractTrainer.stack_new_level_core(self, X, y, models, X_val, y_val, X_unlabeled, level, base_model_names, stack_name, ag_args, ag_args_fit, ag_args_ensemble, included_model_types, excluded_model_types, ensemble_type, name_suffix, get_models_func, refit_full, infer_limit, infer_limit_batch_size, **kwargs)
#     670 fit_kwargs = dict(num_classes=self.num_classes)
#     672 # FIXME: TODO: v0.1 X_unlabeled isn't cached so it won't be available during refit_full or fit_extra.
# --> 673 return self._train_multi(
#     674     X=X_init,
#     675     y=y,
#     676     X_val=X_val,
#     677     y_val=y_val,
#     678     X_unlabeled=X_unlabeled,
#     679     models=models,
#     680     level=level,
#     681     stack_name=stack_name,
#     682     compute_score=compute_score,
#     683     fit_kwargs=fit_kwargs,
#     684     **kwargs,
#     685 )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:2321, in AbstractTrainer._train_multi(self, X, y, models, hyperparameter_tune_kwargs, feature_prune_kwargs, k_fold, n_repeats, n_repeat_start, time_limit, **kwargs)
#    2319 if n_repeat_start == 0:
#    2320     time_start = time.time()
# -> 2321     model_names_trained = self._train_multi_initial(
#    2322         X=X,
#    2323         y=y,
#    2324         models=models,
#    2325         k_fold=k_fold,
#    2326         n_repeats=n_repeats_initial,
#    2327         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2328         feature_prune_kwargs=feature_prune_kwargs,
#    2329         time_limit=time_limit,
#    2330         **kwargs,
#    2331     )
#    2332     n_repeat_start = n_repeats_initial
#    2333     if time_limit is not None:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:2170, in AbstractTrainer._train_multi_initial(self, X, y, models, k_fold, n_repeats, hyperparameter_tune_kwargs, time_limit, feature_prune_kwargs, **kwargs)
#    2168 else:
#    2169     time_ratio = hpo_time_ratio if hpo_enabled else 1
# -> 2170     models = self._train_multi_fold(
#    2171         models=models,
#    2172         hyperparameter_tune_kwargs=hyperparameter_tune_kwargs,
#    2173         k_fold_start=0,
#    2174         k_fold_end=k_fold,
#    2175         n_repeats=n_repeats,
#    2176         n_repeat_start=0,
#    2177         time_limit=time_limit,
#    2178         time_split=time_split,
#    2179         time_ratio=time_ratio,
#    2180         **fit_args,
#    2181     )
#    2183 multi_fold_time_elapsed = time.time() - multi_fold_time_start
#    2184 if time_limit is not None:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:2278, in AbstractTrainer._train_multi_fold(self, X, y, models, time_limit, time_split, time_ratio, hyperparameter_tune_kwargs, **kwargs)
#    2276         time_start_model = time.time()
#    2277         time_left = time_limit - (time_start_model - time_start)
# -> 2278 model_name_trained_lst = self._train_single_full(
#    2279     X, y, model, time_limit=time_left, hyperparameter_tune_kwargs=hyperparameter_tune_kwargs_model, **kwargs
#    2280 )
#    2282 if self.low_memory:
#    2283     del model
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:2051, in AbstractTrainer._train_single_full(self, X, y, model, X_unlabeled, X_val, y_val, X_pseudo, y_pseudo, feature_prune, hyperparameter_tune_kwargs, stack_name, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, level, time_limit, fit_kwargs, compute_score, total_resources, **kwargs)
#    2047         bagged_model_fit_kwargs = self._get_bagged_model_fit_kwargs(
#    2048             k_fold=k_fold, k_fold_start=k_fold_start, k_fold_end=k_fold_end, n_repeats=n_repeats, n_repeat_start=n_repeat_start
#    2049         )
#    2050         model_fit_kwargs.update(bagged_model_fit_kwargs)
# -> 2051     model_names_trained = self._train_and_save(
#    2052         X=X,
#    2053         y=y,
#    2054         model=model,
#    2055         X_val=X_val,
#    2056         y_val=y_val,
#    2057         X_unlabeled=X_unlabeled,
#    2058         stack_name=stack_name,
#    2059         level=level,
#    2060         compute_score=compute_score,
#    2061         total_resources=total_resources,
#    2062         **model_fit_kwargs,
#    2063     )
#    2064 self.save()
#    2065 return model_names_trained
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:1733, in AbstractTrainer._train_and_save(self, X, y, model, X_val, y_val, stack_name, level, compute_score, total_resources, **model_fit_kwargs)
#    1731     model = self._train_single(X_w_pseudo, y_w_pseudo, model, X_val, y_val, **model_fit_kwargs)
#    1732 else:
# -> 1733     model = self._train_single(X, y, model, X_val, y_val, total_resources=total_resources, **model_fit_kwargs)
#    1735 fit_end_time = time.time()
#    1736 if self.weight_evaluation:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/trainer/abstract_trainer.py:1684, in AbstractTrainer._train_single(self, X, y, model, X_val, y_val, total_resources, **model_fit_kwargs)
#    1679 def _train_single(self, X, y, model: AbstractModel, X_val=None, y_val=None, total_resources=None, **model_fit_kwargs) -> AbstractModel:
#    1680     """
#    1681     Trains model but does not add the trained model to this Trainer.
#    1682     Returns trained model object.
#    1683     """
# -> 1684     model = model.fit(X=X, y=y, X_val=X_val, y_val=y_val, total_resources=total_resources, **model_fit_kwargs)
#    1685     return model
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/models/abstract/abstract_model.py:829, in AbstractModel.fit(self, **kwargs)
#     827 self.validate_fit_resources(**kwargs)
#     828 self._validate_fit_memory_usage(**kwargs)
# --> 829 out = self._fit(**kwargs)
#     830 if out is None:
#     831     out = self
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/models/ensemble/stacker_ensemble_model.py:169, in StackerEnsembleModel._fit(self, X, y, compute_base_preds, time_limit, **kwargs)
#     167 if time_limit is not None:
#     168     time_limit = time_limit - (time.time() - start_time)
# --> 169 return super()._fit(X=X, y=y, time_limit=time_limit, **kwargs)
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:250, in BaggedEnsembleModel._fit(self, X, y, X_val, y_val, X_pseudo, y_pseudo, k_fold, k_fold_start, k_fold_end, n_repeats, n_repeat_start, groups, _skip_oof, **kwargs)
#     248 save_bag_folds = self.params.get("save_bag_folds", True)
#     249 if k_fold == 1:
# --> 250     self._fit_single(X=X, y=y, model_base=model_base, use_child_oof=use_child_oof, skip_oof=_skip_oof, **kwargs)
#     251     return self
#     252 else:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/core/models/ensemble/bagged_ensemble_model.py:416, in BaggedEnsembleModel._fit_single(self, X, y, model_base, use_child_oof, time_limit, skip_oof, **kwargs)
#     414 time_start_predict = time.time()
#     415 if model_base._get_tags().get("valid_oof", False):
# --> 416     self._oof_pred_proba = model_base.get_oof_pred_proba(X=X, y=y)
#     417 else:
#     418     logger.warning(
#     419         "\tWARNING: `use_child_oof` was specified but child model does not have a dedicated `get_oof_pred_proba` method. This model may have heavily overfit validation scores."
#     420     )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/models/knn/knn_model.py:115, in KNNModel.get_oof_pred_proba(self, X, normalize, **kwargs)
#     113 def get_oof_pred_proba(self, X, normalize=None, **kwargs):
#     114     """X should be the same X passed to `.fit`"""
# --> 115     y_oof_pred_proba = self._get_oof_pred_proba(X=X, **kwargs)
#     116     if normalize is None:
#     117         normalize = self.normalize_pred_probas
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/models/knn/knn_model.py:129, in KNNModel._get_oof_pred_proba(self, X, **kwargs)
#     127     y_oof_pred_proba = KNeighborsClassifierLOOMixin.predict_proba_loo(self.model)
#     128 else:
# --> 129     y_oof_pred_proba = KNeighborsRegressorLOOMixin.predict_loo(self.model)
#     130 y_oof_pred_proba = self._convert_proba_to_unified_form(y_oof_pred_proba)
#     131 if X is not None and self._X_unused_index:
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/autogluon/tabular/models/knn/_knn_loo_variants.py:115, in KNeighborsRegressorLOOMixin.predict_loo(self)
#     106 @staticmethod
#     107 def predict_loo(self):
#     108     """Predict the target for the training data via leave-one-out.
#     109
#     110     Returns
#    (...)
#     113         Target values.
#     114     """
# --> 115     neigh_dist, neigh_ind = self.kneighbors()
#     117     weights = _get_weights(neigh_dist, self.weights)
#     119     _y = self._y
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/sklearn/neighbors/_base.py:824, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     817 use_pairwise_distances_reductions = (
#     818     self._fit_method == "brute"
#     819     and ArgKmin.is_usable_for(
#     820         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#     821     )
#     822 )
#     823 if use_pairwise_distances_reductions:
# --> 824     results = ArgKmin.compute(
#     825         X=X,
#     826         Y=self._fit_X,
#     827         k=n_neighbors,
#     828         metric=self.effective_metric_,
#     829         metric_kwargs=self.effective_metric_params_,
#     830         strategy="auto",
#     831         return_distance=return_distance,
#     832     )
#     834 elif (
#     835     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#     836 ):
#     837     results = _kneighbors_from_graph(
#     838         X, n_neighbors=n_neighbors, return_distance=return_distance
#     839     )
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:289, in ArgKmin.compute(cls, X, Y, k, metric, chunk_size, metric_kwargs, strategy, return_distance)
#     277     return ArgKmin64.compute(
#     278         X=X,
#     279         Y=Y,
#    (...)
#     285         return_distance=return_distance,
#     286     )
#     288 if X.dtype == Y.dtype == np.float32:
# --> 289     return ArgKmin32.compute(
#     290         X=X,
#     291         Y=Y,
#     292         k=k,
#     293         metric=metric,
#     294         chunk_size=chunk_size,
#     295         metric_kwargs=metric_kwargs,
#     296         strategy=strategy,
#     297         return_distance=return_distance,
#     298     )
#     300 raise ValueError(
#     301     "Only float64 or float32 datasets pairs are supported at this time, "
#     302     f"got: X.dtype={X.dtype} and Y.dtype={Y.dtype}."
#     303 )
#
# File sklearn/metrics/_pairwise_distances_reduction/_argkmin.pyx:584, in sklearn.metrics._pairwise_distances_reduction._argkmin.ArgKmin32.compute()
#
# File ~/anaconda3/envs/tomato/lib/python3.9/site-packages/threadpoolctl.py:440, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     437 def __enter__(self):
#     438     return self
# --> 440 def __exit__(self, type, value, traceback):
#     441     self.restore_original_limits()
#     443 @classmethod
#     444 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
### data preprocess
# input data import
input_data = pd.read_csv('2023_smartFarm_AI_hackathon_dataset.csv')

# 데이터셋을 data, target으로 변수분리
data = input_data.iloc[:,:-1]
target = input_data.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# %%
### RMSE, R2 evaluateß
# AutoGluon 모델을 저장
loaded_predictor = TabularPredictor.load(output_directory)  # 모델의 저장 경로를 지정

# 테스트 데이터 준비
test_df = TabularDataset(X_test) 
prediction = loaded_predictor.predict(test_df)

# RMSE, R2 계산
rmse = np.sqrt(mean_squared_error(y_test, prediction))
r2score = r2_score(y_test, prediction)

# %%
### OUTPUT ###
print("RMSE:", rmse)
print("R2_score:", r2score)
# Out:
# RMSE: 16741.13337970821
# R2_score: 0.9991927446395391
